# %%
hasil
# Out:
# Reliability analysis
# Call: alpha(x = data_matrix, check.keys = TRUE)
#
#   raw_alpha std.alpha G6(smc) average_r S/N  ase mean   sd median_r
#       0.73      0.72    0.72     0.048 2.5 0.07 0.54 0.12     0.05
#
#     95% confidence boundaries
#          lower alpha upper
# Feldt     0.57  0.73  0.85
# Duhachek  0.59  0.73  0.86
#
#  Reliability if an item is dropped:
#      raw_alpha std.alpha G6(smc) average_r S/N var.r med.r
# X1        0.73      0.72    0.73     0.049 2.5 0.035 0.050
# X2        0.73      0.72    0.73     0.050 2.6 0.035 0.055
# X3-       0.72      0.71    0.72     0.049 2.5 0.036 0.050
# X4        0.72      0.71    0.72     0.047 2.4 0.036 0.050
# X5-       0.73      0.72    0.73     0.049 2.5 0.035 0.050
# X6        0.73      0.72    0.72     0.049 2.5 0.036 0.054
# X7        0.71      0.70    0.71     0.046 2.3 0.036 0.046
# X8        0.73      0.72    0.72     0.049 2.5 0.035 0.055
# X9        0.72      0.71    0.72     0.048 2.5 0.035 0.050
# ...

# %%
nama_file <- "/kaggle/input/datauntukujireliabilitas/Data utk SPSS PSikology.csv"
data <- read.csv(nama_file,sep=";")
data_matrix <- as.matrix(data[, -1])
library(psych)
hasil <- alpha(data_matrix, check.keys = TRUE)
# Out:
# Warning message in cor.smooth(r):
# “Matrix was not positive definite, smoothing was done”
# Warning message in alpha(data_matrix, check.keys = TRUE):
# “Some items were negatively correlated with the first principal component and were automatically reversed.
#  This is indicated by a negative sign for the variable name.”
# In smc, smcs < 0 were set to .0
#
# In smc, smcs < 0 were set to .0
#
# In smc, smcs < 0 were set to .0
#
# In smc, smcs < 0 were set to .0
#
# In smc, smcs < 0 were set to .0
#
# In smc, smcs < 0 were set to .0
#
# In smc, smcs < 0 were set to .0
#
# In smc, smcs < 0 were set to .0
#
# In smc, smcs < 0 were set to .0
#
# In smc, smcs < 0 were set to .0
#
# In smc, smcs < 0 were set to .0
#
# In smc, smcs < 0 were set to .0
#
# In smc, smcs < 0 were set to .0
#
# In smc, smcs < 0 were set to .0
#
# In smc, smcs < 0 were set to .0
#
# In smc, smcs < 0 were set to .0
#
# In smc, smcs < 0 were set to .0
#
# In smc, smcs < 0 were set to .0
#
# ...
